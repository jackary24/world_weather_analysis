# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time
import gmaps

from scipy.stats import linregress
from citipy import citipy
from config import weather_api_key
from config import g_key
from datetime import datetime

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

# %%
cities=[]

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):

    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    city_url = url + "&q=" + city.replace(" ","+")

    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descrip = city_weather['weather'][0]['description']

        city_data.append({"City": city.title(),\
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_descrip})

    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nioro
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | labuhan
# Processing Record 7 of Set 1 | lebu
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | harlingen
# Processing Record 10 of Set 1 | rio grande
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | carnarvon
# Processing Record 13 of Set 1 | opuwo
# Processing Record 14 of Set 1 | kodiak
# Processing Record 15 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | katsuura
# Processing Record 19 of Set 1 | harqalah
# Processing Record 20 of Set 1 | dikson
# Processing Record 21 of Set 1 | ribeira grande
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | ostersund
# Processing Record 24 of Set 1 | sangar
# Processing Record 25 of Set 1 | taizhou
# Processing Record 26 of Set 1 | tasiilaq
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | katobu
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | kon tum
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | nanortalik
# Processing Record 33 of Set 1 | salalah
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | tiksi
# Processing Record 36 of Set 1 | san luis
# Processing Record 37 of Set 1 | qaanaaq
# Processing Record 38 of Set 1 | san patricio
# Processing Record 39 of Set 1 | namtsy
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | hobyo
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | georgetown
# Processing Record 44 of Set 1 | chunskiy
# Processing Record 45 of Set 1 | vestmannaeyjar
# Processing Record 46 of Set 1 | arraial do cabo
# Processing Record 47 of Set 1 | eureka
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | bambous virieux
# Processing Record 50 of Set 1 | thompson
# Processing Record 1 of Set 2 | acajutla
# Processing Record 2 of Set 2 | bethel
# Processing Record 3 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 4 of Set 2 | pierre
# Processing Record 5 of Set 2 | deputatskiy
# Processing Record 6 of Set 2 | port elizabeth
# Processing Record 7 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 2 | diamantino
# Processing Record 9 of Set 2 | mahibadhoo
# Processing Record 10 of Set 2 | talnakh
# Processing Record 11 of Set 2 | eskisehir
# Processing Record 12 of Set 2 | coquimbo
# Processing Record 13 of Set 2 | upernavik
# Processing Record 14 of Set 2 | saint-philippe
# Processing Record 15 of Set 2 | ozieri
# Processing Record 16 of Set 2 | maragogi
# Processing Record 17 of Set 2 | temaraia
# City not found. Skipping...
# Processing Record 18 of Set 2 | nyurba
# Processing Record 19 of Set 2 | manggar
# Processing Record 20 of Set 2 | flinders
# Processing Record 21 of Set 2 | montague
# Processing Record 22 of Set 2 | punta arenas
# Processing Record 23 of Set 2 | tuatapere
# Processing Record 24 of Set 2 | niceville
# Processing Record 25 of Set 2 | houston
# Processing Record 26 of Set 2 | dicabisagan
# Processing Record 27 of Set 2 | yulara
# Processing Record 28 of Set 2 | avarua
# Processing Record 29 of Set 2 | wucheng
# Processing Record 30 of Set 2 | tonekabon
# Processing Record 31 of Set 2 | kloulklubed
# Processing Record 32 of Set 2 | atuona
# Processing Record 33 of Set 2 | port hawkesbury
# Processing Record 34 of Set 2 | richards bay
# Processing Record 35 of Set 2 | padang
# Processing Record 36 of Set 2 | cabo san lucas
# Processing Record 37 of Set 2 | gravdal
# Processing Record 38 of Set 2 | fortuna
# Processing Record 39 of Set 2 | atar
# Processing Record 40 of Set 2 | esso
# Processing Record 41 of Set 2 | ushuaia
# Processing Record 42 of Set 2 | marang
# Processing Record 43 of Set 2 | bluff
# Processing Record 44 of Set 2 | mar del plata
# Processing Record 45 of Set 2 | atambua
# Processing Record 46 of Set 2 | pevek
# Processing Record 47 of Set 2 | paamiut
# Processing Record 48 of Set 2 | kalanguy
# Processing Record 49 of Set 2 | umm jarr
# City not found. Skipping...
# Processing Record 50 of Set 2 | new norfolk
# Processing Record 1 of Set 3 | esperance
# Processing Record 2 of Set 3 | moscow
# Processing Record 3 of Set 3 | tura
# Processing Record 4 of Set 3 | dawson creek
# Processing Record 5 of Set 3 | barrow
# Processing Record 6 of Set 3 | leningradskiy
# Processing Record 7 of Set 3 | vila velha
# Processing Record 8 of Set 3 | zhuanghe
# Processing Record 9 of Set 3 | iqaluit
# Processing Record 10 of Set 3 | kayanza
# Processing Record 11 of Set 3 | makakilo city
# Processing Record 12 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 3 | cape coast
# Processing Record 14 of Set 3 | bukachacha
# Processing Record 15 of Set 3 | talcahuano
# Processing Record 16 of Set 3 | lesnoye
# Processing Record 17 of Set 3 | faanui
# Processing Record 18 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 3 | funtua
# Processing Record 21 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 22 of Set 3 | grand gaube
# Processing Record 23 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 3 | ilulissat
# Processing Record 25 of Set 3 | harper
# Processing Record 26 of Set 3 | guajara-mirim
# City not found. Skipping...
# Processing Record 27 of Set 3 | nikolskoye
# Processing Record 28 of Set 3 | uporovo
# Processing Record 29 of Set 3 | mogadishu
# Processing Record 30 of Set 3 | abha
# Processing Record 31 of Set 3 | torbay
# Processing Record 32 of Set 3 | lompoc
# Processing Record 33 of Set 3 | gornopravdinsk
# Processing Record 34 of Set 3 | saint george
# Processing Record 35 of Set 3 | gubkinskiy
# Processing Record 36 of Set 3 | mahebourg
# Processing Record 37 of Set 3 | karasjok
# Processing Record 38 of Set 3 | tuktoyaktuk
# Processing Record 39 of Set 3 | castro
# Processing Record 40 of Set 3 | zyryanka
# Processing Record 41 of Set 3 | jinchengjiang
# City not found. Skipping...
# Processing Record 42 of Set 3 | sao gabriel da cachoeira
# Processing Record 43 of Set 3 | namibe
# Processing Record 44 of Set 3 | pacifica
# Processing Record 45 of Set 3 | port lincoln
# Processing Record 46 of Set 3 | tatawin
# Processing Record 47 of Set 3 | karakendzha
# City not found. Skipping...
# Processing Record 48 of Set 3 | pringsewu
# Processing Record 49 of Set 3 | beruni
# City not found. Skipping...
# Processing Record 50 of Set 3 | lata
# Processing Record 1 of Set 4 | hami
# Processing Record 2 of Set 4 | agadez
# Processing Record 3 of Set 4 | khatanga
# Processing Record 4 of Set 4 | tunduru
# City not found. Skipping...
# Processing Record 5 of Set 4 | chokurdakh
# Processing Record 6 of Set 4 | dasoguz
# Processing Record 7 of Set 4 | thinadhoo
# Processing Record 8 of Set 4 | severo-kurilsk
# Processing Record 9 of Set 4 | bubaque
# Processing Record 10 of Set 4 | pestovo
# Processing Record 11 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 13 of Set 4 | jitra
# Processing Record 14 of Set 4 | gusinoye ozero
# Processing Record 15 of Set 4 | hamilton
# Processing Record 16 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 4 | olga
# Processing Record 18 of Set 4 | suntar
# Processing Record 19 of Set 4 | sola
# Processing Record 20 of Set 4 | tutoia
# Processing Record 21 of Set 4 | bredasdorp
# Processing Record 22 of Set 4 | fairbanks
# Processing Record 23 of Set 4 | luderitz
# Processing Record 24 of Set 4 | longyearbyen
# Processing Record 25 of Set 4 | lang son
# Processing Record 26 of Set 4 | tynda
# Processing Record 27 of Set 4 | leh
# Processing Record 28 of Set 4 | muros
# Processing Record 29 of Set 4 | sioux lookout
# Processing Record 30 of Set 4 | sistranda
# Processing Record 31 of Set 4 | yendi
# Processing Record 32 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 4 | teya
# Processing Record 34 of Set 4 | dezful
# Processing Record 35 of Set 4 | sur
# Processing Record 36 of Set 4 | matagalpa
# Processing Record 37 of Set 4 | tete
# Processing Record 38 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 4 | zhigansk
# Processing Record 40 of Set 4 | coos bay
# Processing Record 41 of Set 4 | lipno
# Processing Record 42 of Set 4 | campo verde
# Processing Record 43 of Set 4 | lavrentiya
# Processing Record 44 of Set 4 | pingliang
# Processing Record 45 of Set 4 | harare
# Processing Record 46 of Set 4 | maputo
# Processing Record 47 of Set 4 | kuytun
# Processing Record 48 of Set 4 | poum
# Processing Record 49 of Set 4 | soroti
# Processing Record 50 of Set 4 | camacha
# Processing Record 1 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 5 | batouri
# Processing Record 3 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 5 | follonica
# Processing Record 5 of Set 5 | ostrovnoy
# Processing Record 6 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 5 | cidreira
# Processing Record 8 of Set 5 | tabira
# Processing Record 9 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 5 | sassandra
# Processing Record 11 of Set 5 | khanpur
# Processing Record 12 of Set 5 | sao filipe
# Processing Record 13 of Set 5 | oak ridge
# Processing Record 14 of Set 5 | sarangani
# Processing Record 15 of Set 5 | naze
# Processing Record 16 of Set 5 | quatre cocos
# Processing Record 17 of Set 5 | pimentel
# Processing Record 18 of Set 5 | makat
# Processing Record 19 of Set 5 | morgan city
# Processing Record 20 of Set 5 | taureni
# Processing Record 21 of Set 5 | santa cruz de la palma
# Processing Record 22 of Set 5 | hithadhoo
# Processing Record 23 of Set 5 | shimoda
# Processing Record 24 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 25 of Set 5 | umri
# Processing Record 26 of Set 5 | vanimo
# Processing Record 27 of Set 5 | yar-sale
# Processing Record 28 of Set 5 | kizukuri
# Processing Record 29 of Set 5 | muromtsevo
# Processing Record 30 of Set 5 | grafton
# Processing Record 31 of Set 5 | srednekolymsk
# Processing Record 32 of Set 5 | kantabanji
# Processing Record 33 of Set 5 | qaqortoq
# Processing Record 34 of Set 5 | teguise
# Processing Record 35 of Set 5 | churu
# Processing Record 36 of Set 5 | la ronge
# Processing Record 37 of Set 5 | moree
# Processing Record 38 of Set 5 | vestmanna
# Processing Record 39 of Set 5 | sal rei
# Processing Record 40 of Set 5 | saurimo
# Processing Record 41 of Set 5 | chuy
# Processing Record 42 of Set 5 | balikpapan
# Processing Record 43 of Set 5 | port blair
# Processing Record 44 of Set 5 | opaka
# Processing Record 45 of Set 5 | lagoa
# Processing Record 46 of Set 5 | cherskiy
# Processing Record 47 of Set 5 | banda aceh
# Processing Record 48 of Set 5 | sorada
# Processing Record 49 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 50 of Set 5 | bolshiye uki
# City not found. Skipping...
# Processing Record 1 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 6 | paita
# Processing Record 3 of Set 6 | plouzane
# Processing Record 4 of Set 6 | vila franca do campo
# Processing Record 5 of Set 6 | olafsvik
# Processing Record 6 of Set 6 | hofn
# Processing Record 7 of Set 6 | usinsk
# Processing Record 8 of Set 6 | spalene porici
# Processing Record 9 of Set 6 | hermanus
# Processing Record 10 of Set 6 | bathsheba
# Processing Record 11 of Set 6 | urengoy
# Processing Record 12 of Set 6 | comodoro rivadavia
# Processing Record 13 of Set 6 | palana
# Processing Record 14 of Set 6 | caravelas
# Processing Record 15 of Set 6 | sao joao da barra
# Processing Record 16 of Set 6 | ghanzi
# Processing Record 17 of Set 6 | trincomalee
# Processing Record 18 of Set 6 | portland
# Processing Record 19 of Set 6 | alofi
# Processing Record 20 of Set 6 | taoudenni
# Processing Record 21 of Set 6 | kavieng
# Processing Record 22 of Set 6 | andros town
# Processing Record 23 of Set 6 | cockburn town
# Processing Record 24 of Set 6 | ivanava
# Processing Record 25 of Set 6 | dakar
# Processing Record 26 of Set 6 | aklavik
# Processing Record 27 of Set 6 | guerrero negro
# Processing Record 28 of Set 6 | kant
# Processing Record 29 of Set 6 | voh
# Processing Record 30 of Set 6 | abnub
# Processing Record 31 of Set 6 | florence
# Processing Record 32 of Set 6 | faya
# Processing Record 33 of Set 6 | srednebelaya
# Processing Record 34 of Set 6 | gopichettipalaiyam
# City not found. Skipping...
# Processing Record 35 of Set 6 | bandarbeyla
# Processing Record 36 of Set 6 | acarau
# Processing Record 37 of Set 6 | alta floresta
# Processing Record 38 of Set 6 | krasnoselkup
# Processing Record 39 of Set 6 | carutapera
# Processing Record 40 of Set 6 | la palma
# Processing Record 41 of Set 6 | araouane
# Processing Record 42 of Set 6 | tocopilla
# Processing Record 43 of Set 6 | margate
# Processing Record 44 of Set 6 | chilca
# Processing Record 45 of Set 6 | port hedland
# Processing Record 46 of Set 6 | yerbogachen
# Processing Record 47 of Set 6 | lithgow
# Processing Record 48 of Set 6 | geraldton
# Processing Record 49 of Set 6 | kruisfontein
# Processing Record 50 of Set 6 | porto velho
# Processing Record 1 of Set 7 | bayonet point
# Processing Record 2 of Set 7 | narsaq
# Processing Record 3 of Set 7 | xingcheng
# Processing Record 4 of Set 7 | dunedin
# Processing Record 5 of Set 7 | sulangan
# Processing Record 6 of Set 7 | tupiza
# Processing Record 7 of Set 7 | east london
# Processing Record 8 of Set 7 | werda
# Processing Record 9 of Set 7 | hasaki
# Processing Record 10 of Set 7 | coahuayana
# Processing Record 11 of Set 7 | dickson
# Processing Record 12 of Set 7 | arlit
# Processing Record 13 of Set 7 | kuching
# Processing Record 14 of Set 7 | zanesville
# Processing Record 15 of Set 7 | souillac
# Processing Record 16 of Set 7 | bellevue
# Processing Record 17 of Set 7 | ilebo
# Processing Record 18 of Set 7 | cururupu
# Processing Record 19 of Set 7 | constitucion
# Processing Record 20 of Set 7 | linchuan
# City not found. Skipping...
# Processing Record 21 of Set 7 | sakakah
# Processing Record 22 of Set 7 | west bay
# Processing Record 23 of Set 7 | nelson bay
# Processing Record 24 of Set 7 | tautira
# Processing Record 25 of Set 7 | ler
# Processing Record 26 of Set 7 | kangaatsiaq
# Processing Record 27 of Set 7 | huarmey
# Processing Record 28 of Set 7 | bengkulu
# Processing Record 29 of Set 7 | belaya gora
# Processing Record 30 of Set 7 | ferme-neuve
# Processing Record 31 of Set 7 | norman wells
# Processing Record 32 of Set 7 | santa maria
# Processing Record 33 of Set 7 | udachnyy
# Processing Record 34 of Set 7 | shenjiamen
# Processing Record 35 of Set 7 | ceska skalice
# Processing Record 36 of Set 7 | saskylakh
# Processing Record 37 of Set 7 | marrakesh
# Processing Record 38 of Set 7 | abu samrah
# Processing Record 39 of Set 7 | mwene-ditu
# Processing Record 40 of Set 7 | batagay
# Processing Record 41 of Set 7 | sitka
# Processing Record 42 of Set 7 | khani
# Processing Record 43 of Set 7 | nouadhibou
# Processing Record 44 of Set 7 | ancud
# Processing Record 45 of Set 7 | sabaudia
# Processing Record 46 of Set 7 | isla mujeres
# Processing Record 47 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 48 of Set 7 | kazbegi
# City not found. Skipping...
# Processing Record 49 of Set 7 | imeni poliny osipenko
# Processing Record 50 of Set 7 | uthal
# Processing Record 1 of Set 8 | aranos
# Processing Record 2 of Set 8 | tabou
# Processing Record 3 of Set 8 | korla
# Processing Record 4 of Set 8 | clyde river
# Processing Record 5 of Set 8 | dogondoutchi
# Processing Record 6 of Set 8 | pangoa
# Processing Record 7 of Set 8 | lokken verk
# City not found. Skipping...
# Processing Record 8 of Set 8 | halifax
# Processing Record 9 of Set 8 | uinskoye
# Processing Record 10 of Set 8 | malchevskaya
# Processing Record 11 of Set 8 | kirkwood
# Processing Record 12 of Set 8 | stromness
# Processing Record 13 of Set 8 | ateptsevo
# Processing Record 14 of Set 8 | mana
# Processing Record 15 of Set 8 | poya
# Processing Record 16 of Set 8 | okhotsk
# Processing Record 17 of Set 8 | sibolga
# Processing Record 18 of Set 8 | tres lagoas
# Processing Record 19 of Set 8 | victoria
# Processing Record 20 of Set 8 | weihe
# Processing Record 21 of Set 8 | yurga
# Processing Record 22 of Set 8 | ahipara
# Processing Record 23 of Set 8 | mareeba
# Processing Record 24 of Set 8 | palamos
# Processing Record 25 of Set 8 | wellin
# Processing Record 26 of Set 8 | sorland
# Processing Record 27 of Set 8 | shelburne
# Processing Record 28 of Set 8 | dinsor
# City not found. Skipping...
# Processing Record 29 of Set 8 | mnogovershinnyy
# Processing Record 30 of Set 8 | taywarah
# Processing Record 31 of Set 8 | bedele
# Processing Record 32 of Set 8 | karaton
# Processing Record 33 of Set 8 | llanes
# Processing Record 34 of Set 8 | gimli
# Processing Record 35 of Set 8 | samarai
# Processing Record 36 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 8 | muroto
# Processing Record 38 of Set 8 | vardo
# Processing Record 39 of Set 8 | kaitangata
# Processing Record 40 of Set 8 | batagay-alyta
# Processing Record 41 of Set 8 | tawnat
# City not found. Skipping...
# Processing Record 42 of Set 8 | umm lajj
# Processing Record 43 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 44 of Set 8 | novikovo
# Processing Record 45 of Set 8 | iskateley
# Processing Record 46 of Set 8 | rocha
# Processing Record 47 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 8 | saint-pierre
# Processing Record 49 of Set 8 | salta
# Processing Record 50 of Set 8 | skjervoy
# Processing Record 1 of Set 9 | kazachka
# Processing Record 2 of Set 9 | pangnirtung
# Processing Record 3 of Set 9 | hammerfest
# Processing Record 4 of Set 9 | felidhoo
# City not found. Skipping...
# Processing Record 5 of Set 9 | matara
# Processing Record 6 of Set 9 | marica
# Processing Record 7 of Set 9 | moron
# Processing Record 8 of Set 9 | pacific grove
# Processing Record 9 of Set 9 | havelock
# Processing Record 10 of Set 9 | kumaliskis
# Processing Record 11 of Set 9 | kouroussa
# Processing Record 12 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 9 | kabugao
# Processing Record 14 of Set 9 | bolotnoye
# Processing Record 15 of Set 9 | airai
# Processing Record 16 of Set 9 | meulaboh
# Processing Record 17 of Set 9 | camacupa
# Processing Record 18 of Set 9 | legnago
# Processing Record 19 of Set 9 | san andres
# Processing Record 20 of Set 9 | kotri
# Processing Record 21 of Set 9 | isangel
# Processing Record 22 of Set 9 | viedma
# Processing Record 23 of Set 9 | keetmanshoop
# Processing Record 24 of Set 9 | provideniya
# Processing Record 25 of Set 9 | santa vitoria
# Processing Record 26 of Set 9 | brookings
# Processing Record 27 of Set 9 | waingapu
# Processing Record 28 of Set 9 | avera
# Processing Record 29 of Set 9 | zhezkazgan
# Processing Record 30 of Set 9 | ponta do sol
# Processing Record 31 of Set 9 | aginskoye
# Processing Record 32 of Set 9 | darnah
# Processing Record 33 of Set 9 | americus
# Processing Record 34 of Set 9 | rafai
# Processing Record 35 of Set 9 | kahului
# Processing Record 36 of Set 9 | broome
# Processing Record 37 of Set 9 | los llanos de aridane
# Processing Record 38 of Set 9 | saint-joseph
# Processing Record 39 of Set 9 | luncavita
# Processing Record 40 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 41 of Set 9 | iquique
# Processing Record 42 of Set 9 | san rafael
# Processing Record 43 of Set 9 | komsomolskiy
# Processing Record 44 of Set 9 | ketchikan
# Processing Record 45 of Set 9 | soyo
# Processing Record 46 of Set 9 | columbus
# Processing Record 47 of Set 9 | farafangana
# Processing Record 48 of Set 9 | burica
# City not found. Skipping...
# Processing Record 49 of Set 9 | tyazhinskiy
# Processing Record 50 of Set 9 | tateyama
# Processing Record 1 of Set 10 | fare
# Processing Record 2 of Set 10 | bandar
# Processing Record 3 of Set 10 | pisco
# Processing Record 4 of Set 10 | port-cartier
# Processing Record 5 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 10 | sao jose da coroa grande
# Processing Record 7 of Set 10 | baft
# Processing Record 8 of Set 10 | devils lake
# Processing Record 9 of Set 10 | new ulm
# Processing Record 10 of Set 10 | rawah
# Processing Record 11 of Set 10 | tuy hoa
# Processing Record 12 of Set 10 | radford
# Processing Record 13 of Set 10 | kaduy
# Processing Record 14 of Set 10 | aberystwyth
# Processing Record 15 of Set 10 | kasama
# Processing Record 16 of Set 10 | kesennuma
# City not found. Skipping...
# Processing Record 17 of Set 10 | huejuquilla el alto
# Processing Record 18 of Set 10 | sai buri
# Processing Record 19 of Set 10 | hervey bay
# Processing Record 20 of Set 10 | touros
# Processing Record 21 of Set 10 | byron bay
# Processing Record 22 of Set 10 | altea
# Processing Record 23 of Set 10 | buraydah
# Processing Record 24 of Set 10 | kungurtug
# Processing Record 25 of Set 10 | huaicheng
# Processing Record 26 of Set 10 | kailua
# Processing Record 27 of Set 10 | la paz
# Processing Record 28 of Set 10 | wewak
# Processing Record 29 of Set 10 | peterhead
# Processing Record 30 of Set 10 | vilyuysk
# Processing Record 31 of Set 10 | nome
# Processing Record 32 of Set 10 | illapel
# Processing Record 33 of Set 10 | barabash
# Processing Record 34 of Set 10 | chifeng
# Processing Record 35 of Set 10 | arusha
# Processing Record 36 of Set 10 | san roque
# Processing Record 37 of Set 10 | arawa
# Processing Record 38 of Set 10 | chicama
# Processing Record 39 of Set 10 | aplahoue
# Processing Record 40 of Set 10 | plettenberg bay
# Processing Record 41 of Set 10 | lerwick
# Processing Record 42 of Set 10 | cam ranh
# Processing Record 43 of Set 10 | iisalmi
# Processing Record 44 of Set 10 | tanga
# Processing Record 45 of Set 10 | san juan de uraba
# Processing Record 46 of Set 10 | karratha
# Processing Record 47 of Set 10 | gambela
# Processing Record 48 of Set 10 | astana
# Processing Record 49 of Set 10 | mayumba
# Processing Record 50 of Set 10 | lhuntshi
# City not found. Skipping...
# Processing Record 1 of Set 11 | yumen
# Processing Record 2 of Set 11 | bilibino
# Processing Record 3 of Set 11 | muravlenko
# Processing Record 4 of Set 11 | mangrol
# Processing Record 5 of Set 11 | mount gambier
# Processing Record 6 of Set 11 | puerto carreno
# Processing Record 7 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 8 of Set 11 | tacuati
# Processing Record 9 of Set 11 | anadyr
# Processing Record 10 of Set 11 | kavaratti
# Processing Record 11 of Set 11 | goderich
# Processing Record 12 of Set 11 | emborion
# Processing Record 13 of Set 11 | myra
# Processing Record 14 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 15 of Set 11 | vangaindrano
# Processing Record 16 of Set 11 | talavera de la reina
# Processing Record 17 of Set 11 | kushmurun
# Processing Record 18 of Set 11 | ozernovskiy
# Processing Record 19 of Set 11 | pangani
# Processing Record 20 of Set 11 | itarema
# Processing Record 21 of Set 11 | aksu
# Processing Record 22 of Set 11 | maniwaki
# Processing Record 23 of Set 11 | maracacume
# Processing Record 24 of Set 11 | toba
# Processing Record 25 of Set 11 | niamey
# Processing Record 26 of Set 11 | antalaha
# Processing Record 27 of Set 11 | chapais
# Processing Record 28 of Set 11 | blind river
# Processing Record 29 of Set 11 | ust-maya
# Processing Record 30 of Set 11 | caluquembe
# Processing Record 31 of Set 11 | whitehorse
# Processing Record 32 of Set 11 | haines junction
# Processing Record 33 of Set 11 | buta
# Processing Record 34 of Set 11 | kjollefjord
# Processing Record 35 of Set 11 | santa lucia
# Processing Record 36 of Set 11 | newport
# Processing Record 37 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 38 of Set 11 | verkhniy avzyan
# Processing Record 39 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 40 of Set 11 | riachao do dantas
# Processing Record 41 of Set 11 | cayenne
# Processing Record 42 of Set 11 | onverwacht
# Processing Record 43 of Set 11 | sheridan
# Processing Record 44 of Set 11 | oranjemund
# Processing Record 45 of Set 11 | boguchany
# Processing Record 46 of Set 11 | yakshur-bodya
# City not found. Skipping...
# Processing Record 47 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 11 | luanda
# Processing Record 49 of Set 11 | cap malheureux
# Processing Record 50 of Set 11 | kichera
# Processing Record 1 of Set 12 | waddan
# Processing Record 2 of Set 12 | encruzilhada do sul
# Processing Record 3 of Set 12 | grand-lahou
# Processing Record 4 of Set 12 | flin flon
# Processing Record 5 of Set 12 | upata
# Processing Record 6 of Set 12 | anar darreh
# City not found. Skipping...
# Processing Record 7 of Set 12 | japura
# Processing Record 8 of Set 12 | berlevag
# Processing Record 9 of Set 12 | klaksvik
# Processing Record 10 of Set 12 | zelenyy bor
# Processing Record 11 of Set 12 | oranjestad
# Processing Record 12 of Set 12 | balkhash
# Processing Record 13 of Set 12 | ambon
# Processing Record 14 of Set 12 | rakiv lis
# Processing Record 15 of Set 12 | cravo norte
# Processing Record 16 of Set 12 | praia da vitoria
# Processing Record 17 of Set 12 | xuddur
# Processing Record 18 of Set 12 | the valley
# Processing Record 19 of Set 12 | luancheng
# Processing Record 20 of Set 12 | ziyang
# Processing Record 21 of Set 12 | muli
# Processing Record 22 of Set 12 | gigmoto
# Processing Record 23 of Set 12 | angoche
# Processing Record 24 of Set 12 | rantepao
# Processing Record 25 of Set 12 | chumikan
# Processing Record 26 of Set 12 | san-pedro
# Processing Record 27 of Set 12 | kaoma
# Processing Record 28 of Set 12 | corinto
# Processing Record 29 of Set 12 | envira
# Processing Record 30 of Set 12 | altamira
# Processing Record 31 of Set 12 | muzaffarpur
# Processing Record 32 of Set 12 | auki
# Processing Record 33 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 34 of Set 12 | kutum
# Processing Record 35 of Set 12 | andenne
# Processing Record 36 of Set 12 | port hardy
# Processing Record 37 of Set 12 | rawson
# Processing Record 38 of Set 12 | sunyani
# Processing Record 39 of Set 12 | hernani
# Processing Record 40 of Set 12 | honiara
# Processing Record 41 of Set 12 | numan
# Processing Record 42 of Set 12 | lorengau
# Processing Record 43 of Set 12 | lensk
# Processing Record 44 of Set 12 | te anau
# Processing Record 45 of Set 12 | necochea
# Processing Record 46 of Set 12 | adre
# Processing Record 47 of Set 12 | jawhar
# Processing Record 48 of Set 12 | angoram
# Processing Record 49 of Set 12 | chabahar
# Processing Record 50 of Set 12 | saqqez
# Processing Record 1 of Set 13 | mananjary
# Processing Record 2 of Set 13 | macau
# Processing Record 3 of Set 13 | borogontsy
# Processing Record 4 of Set 13 | pozhva
# Processing Record 5 of Set 13 | saint anthony
# Processing Record 6 of Set 13 | sun valley
# Processing Record 7 of Set 13 | sangin
# Processing Record 8 of Set 13 | yurginskoye
# Processing Record 9 of Set 13 | isla vista
# Processing Record 10 of Set 13 | ambilobe
# Processing Record 11 of Set 13 | grants pass
# Processing Record 12 of Set 13 | naryan-mar
# Processing Record 13 of Set 13 | husavik
# Processing Record 14 of Set 13 | bosaso
# Processing Record 15 of Set 13 | amarpatan
# Processing Record 16 of Set 13 | san quintin
# Processing Record 17 of Set 13 | kokuy
# Processing Record 18 of Set 13 | swan river
# Processing Record 19 of Set 13 | ayr
# Processing Record 20 of Set 13 | codrington
# Processing Record 21 of Set 13 | turkistan
# Processing Record 22 of Set 13 | atasu
# Processing Record 23 of Set 13 | seymchan
# Processing Record 24 of Set 13 | la belleza
# Processing Record 25 of Set 13 | astoria
# Processing Record 26 of Set 13 | juneau
# Processing Record 27 of Set 13 | hornostayivka
# Processing Record 28 of Set 13 | zonguldak
# Processing Record 29 of Set 13 | gushikawa
# Processing Record 30 of Set 13 | vanavara
# Processing Record 31 of Set 13 | higuey
# City not found. Skipping...
# Processing Record 32 of Set 13 | great falls
# Processing Record 33 of Set 13 | kedrovyy
# Processing Record 34 of Set 13 | kampong thum
# Processing Record 35 of Set 13 | emba
# Processing Record 36 of Set 13 | adrar
# Processing Record 37 of Set 13 | mercedes
# Processing Record 38 of Set 13 | altay
# Processing Record 39 of Set 13 | gweta
# Processing Record 40 of Set 13 | santa rosa
# Processing Record 41 of Set 13 | miandrivazo
# Processing Record 42 of Set 13 | baishishan
# Processing Record 43 of Set 13 | fernley
# Processing Record 44 of Set 13 | santa maria del oro
# Processing Record 45 of Set 13 | ankazoabo
# Processing Record 46 of Set 13 | nishihara
# Processing Record 47 of Set 13 | manicore
# Processing Record 48 of Set 13 | kribi
# Processing Record 49 of Set 13 | eyl
# Processing Record 50 of Set 13 | sarakhs
# Processing Record 1 of Set 14 | vicksburg
# Processing Record 2 of Set 14 | uong bi
# Processing Record 3 of Set 14 | balakhta
# Processing Record 4 of Set 14 | dmitriyev-lgovskiy
# City not found. Skipping...
# Processing Record 5 of Set 14 | yola
# Processing Record 6 of Set 14 | druzhba
# Processing Record 7 of Set 14 | fort-shevchenko
# Processing Record 8 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 14 | akyab
# Processing Record 10 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 14 | jiayuguan
# Processing Record 12 of Set 14 | bakchar
# Processing Record 13 of Set 14 | adeje
# Processing Record 14 of Set 14 | mafeteng
# Processing Record 15 of Set 14 | atyrau
# Processing Record 16 of Set 14 | teknaf
# Processing Record 17 of Set 14 | laguna
# Processing Record 18 of Set 14 | jenison
# Processing Record 19 of Set 14 | hovd
# Processing Record 20 of Set 14 | port macquarie
# Processing Record 21 of Set 14 | zhitikara
# City not found. Skipping...
# Processing Record 22 of Set 14 | horta
# Processing Record 23 of Set 14 | emerald
# Processing Record 24 of Set 14 | abu zabad
# Processing Record 25 of Set 14 | malatya
# Processing Record 26 of Set 14 | dali
# Processing Record 27 of Set 14 | troitsko-pechorsk
# Processing Record 28 of Set 14 | menongue
# Processing Record 29 of Set 14 | maldonado
# Processing Record 30 of Set 14 | zeya
# Processing Record 31 of Set 14 | portlethen
# Processing Record 32 of Set 14 | pudozh
# Processing Record 33 of Set 14 | burewala
# Processing Record 34 of Set 14 | narragansett
# Processing Record 35 of Set 14 | melhus
# Processing Record 36 of Set 14 | alyangula
# Processing Record 37 of Set 14 | konin
# Processing Record 38 of Set 14 | great yarmouth
# Processing Record 39 of Set 14 | carmaux
# Processing Record 40 of Set 14 | esik
# Processing Record 41 of Set 14 | pangkalanbuun
# Processing Record 42 of Set 14 | christchurch
# Processing Record 43 of Set 14 | bossembele
# City not found. Skipping...
# Processing Record 44 of Set 14 | vilanova del cami
# Processing Record 45 of Set 14 | anshun
# Processing Record 46 of Set 14 | sika
# Processing Record 47 of Set 14 | koumac
# Processing Record 48 of Set 14 | yeppoon
# Processing Record 49 of Set 14 | takoradi
# Processing Record 50 of Set 14 | durban
# Processing Record 1 of Set 15 | mhlume
# Processing Record 2 of Set 15 | obukhiv
# Processing Record 3 of Set 15 | natal
# Processing Record 4 of Set 15 | vostok
# Processing Record 5 of Set 15 | gien
# Processing Record 6 of Set 15 | saint-denis
# Processing Record 7 of Set 15 | taltal
# Processing Record 8 of Set 15 | talakan
# Processing Record 9 of Set 15 | egvekinot
# Processing Record 10 of Set 15 | mucurapo
# Processing Record 11 of Set 15 | baruun-urt
# Processing Record 12 of Set 15 | pauini
# Processing Record 13 of Set 15 | dengzhou
# Processing Record 14 of Set 15 | maraa
# Processing Record 15 of Set 15 | fuling
# Processing Record 16 of Set 15 | skibbereen
# Processing Record 17 of Set 15 | yomitan
# City not found. Skipping...
# Processing Record 18 of Set 15 | arkhara
# Processing Record 19 of Set 15 | sao joao del rei
# Processing Record 20 of Set 15 | diphu
# Processing Record 21 of Set 15 | tecoanapa
# Processing Record 22 of Set 15 | dharmabad
# Processing Record 23 of Set 15 | constantine
# Processing Record 24 of Set 15 | kamaishi
# Processing Record 25 of Set 15 | galesong
# Processing Record 26 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 27 of Set 15 | tabukiniberu
# City not found. Skipping...
# Processing Record 28 of Set 15 | grindavik
# Processing Record 29 of Set 15 | brae
# Processing Record 30 of Set 15 | bairiki
# Processing Record 31 of Set 15 | umba
# Processing Record 32 of Set 15 | abu dhabi
# Processing Record 33 of Set 15 | ruteng
# Processing Record 34 of Set 15 | miri
# Processing Record 35 of Set 15 | tamasane
# Processing Record 36 of Set 15 | nizhnevartovsk
# Processing Record 37 of Set 15 | kasongo-lunda
# Processing Record 38 of Set 15 | beibei
# Processing Record 39 of Set 15 | bambanglipuro
# Processing Record 40 of Set 15 | gari
# Processing Record 41 of Set 15 | dillon
# Processing Record 42 of Set 15 | arendonk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)

new_column_order = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed', "Description"]
city_data_df=city_data_df[new_column_order]
output_data_file = "weatherpy_database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
